# %%
import pandas as pd

# %% [markdown]
# ### The first dataset was found on Google Dataset Search (https://www.johnsnowlabs.com/). Information of 2019.

# %%
url="https://raw.githubusercontent.com/danieltp92/datasets/main/data.csv"
data = pd.read_csv(url)
data
# Out:
#       Age  Gender                   Country      State  Is_Self_Employed  \
# 0    25.0    Male  United States of America   Nebraska             False
# 1    51.0    Male  United States of America   Nebraska             False
# 2    27.0    Male  United States of America   Illinois             False
# 3    37.0    Male  United States of America   Nebraska             False
# 4    46.0    Male  United States of America   Nebraska             False
# ..    ...     ...                       ...        ...               ...
# 347  27.0    Male                     India        NaN             False
# 348  48.0    Male  United States of America  Louisiana              True
# 349  50.0    Male                     India        NaN              True
# 350  30.0  Female                     India        NaN             False
# 351  24.0  Female  United States of America     Oregon             False
#
#     Is_Family_History_of_Mental_Illness  Is_Treatment_Sought  \
# ...

# %% [markdown]
# ### Reviewing the information from the dataset, we can see that it has 18 variables and a total of 352 records

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 18 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Age                                      351 non-null    float64
#  1   Gender                                   345 non-null    object
#  2   Country                                  352 non-null    object
#  3   State                                    204 non-null    object
#  4   Is_Self_Employed                         352 non-null    bool
#  5   Is_Family_History_of_Mental_Illness      266 non-null    object
#  6   Is_Treatment_Sought                      352 non-null    bool
#  7   Interference_With_Work                   352 non-null    object
#  8   Number_of_Employees_in_Organization      304 non-null    object
#  9   Is_Employer_Tech_Company                 304 non-null    object
# ...

# %% [markdown]
# ## Columns relevant for study

# %% [markdown]
# #### The country and number of countries would be relevant to see a patern in the relationship between tech companies and how impact in mental health

# %%
list_country = data['Country'].unique()
list_country
# Out:
# array(['United States of America', 'United Kingdom', 'Netherlands',
#        'Canada', 'Turkey', 'Belgium', 'Croatia', 'Ghana', 'Norway',
#        'Portugal', 'Switzerland', 'Pakistan', 'Poland', 'Spain', 'India',
#        'Brazil', 'Austria', 'Germany', 'Israel', 'Mexico', 'Italy',
#        'New Zealand', 'Ireland', 'France', 'Algeria', 'Hong Kong',
#        'Indonesia', 'South Africa', 'Afghanistan', 'Estonia', 'Greece',
#        'Japan'], dtype=object)

# %% [markdown]
# #### We make a count of how many countries are involved in the study

# %%
def num_elem(list):
    count = 0
    for element in list:
        count += 1
    return count

print("Number of countries: ", num_elem(list_country))
# Out:
# Number of countries:  32

# %% [markdown]
# #### We check the size of the companies and found that some records need to be cleaned due the fact that the system take some as dates.

# %%
print(data['Number_of_Employees_in_Organization'].unique())
# Out:
# ['26-100' '100-500' nan '25-Jun' 'More than 1000' '500-1000' '5-Jan']

# %% [markdown]
# #### We check how many companies are related to technology

# %%
tech_df = pd.DataFrame(data, columns=['Is_Employer_Tech_Company'])
dups = tech_df.pivot_table(columns=['Is_Employer_Tech_Company'], aggfunc='size')
print(dups)
# Out:
# Is_Employer_Tech_Company
# False     97
# True     207
# dtype: int64

# %% [markdown]
# #### The age is relevant to figure if it has any relationship with mental health. Also we can make groups for a data model.

# %%
tech_df = pd.DataFrame(data, columns=['Age'])
dups = tech_df.pivot_table(columns=['Age'], aggfunc='size')
print(dups)
# Out:
# Age
# 19.0     4
# 20.0     1
# 21.0     1
# 22.0     5
# 23.0     7
# 24.0    11
# 25.0     9
# 26.0    11
# 27.0    17
# 28.0    21
# 29.0    11
# 30.0    23
# 31.0    12
# 32.0    15
# 33.0    10
# 34.0    18
# 35.0    12
# 36.0    13
# 37.0    16
# 38.0    18
# 39.0    11
# 40.0    13
# 41.0    11
# 42.0    14
# 43.0     4
# 44.0     2
# 45.0    10
# 46.0     4
# 47.0     7
# 48.0     4
# 49.0     8
# 50.0     5
# 51.0     4
# 52.0     1
# 53.0     5
# 54.0     2
# 55.0     3
# 56.0     1
# 58.0     1
# 59.0     3
# 60.0     1
# 63.0     1
# 64.0     1
# dtype: int64

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### The second dataset was found on Kaggle (https://www.kaggle.com/). Information of 2014 - 2016.

# %%
url2 = "https://raw.githubusercontent.com/danieltp92/datasets/main/survey.csv"
survey = pd.read_csv(url2)
survey
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0      8/27/2014 11:29   37  Female   United States    IL           NaN
# 1      8/27/2014 11:29   44       M   United States    IN           NaN
# 2      8/27/2014 11:29   32    Male          Canada   NaN           NaN
# 3      8/27/2014 11:29   31    Male  United Kingdom   NaN           NaN
# 4      8/27/2014 11:30   31    Male   United States    TX           NaN
# ...                ...  ...     ...             ...   ...           ...
# 1254   9/12/2015 11:17   26    male  United Kingdom   NaN            No
# 1255    9/26/2015 1:07   32    Male   United States    IL            No
# 1256   11/7/2015 12:36   34    male   United States    CA            No
# 1257  11/30/2015 21:25   46       f   United States    NC            No
# 1258    2/1/2016 23:04   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %% [markdown]
# ### Reviewing the information from the dataset, we can see that it has 28 variables and a total of 1259 records.

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %% [markdown]
# ## Columns relevant for study

# %% [markdown]
# #### The country and number of countries would be relevant to see a patern in the relationship between tech companies and how impact in mental health

# %%
survey_df = survey.copy()
survey_df['Date_time'] = survey_df['Timestamp'].astype('datetime64[ns]')

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %% [markdown]
# #### The dataset has a variable with datetime information. Review what is the oldest and newest date of the records.

# %%
print(survey_df.Date_time.max())
# Out:
# 2016-02-01 23:04:00

# %%
print(survey_df.Date_time.min())
# Out:
# 2014-08-27 11:29:00

# %% [markdown]
# #### The country and number of countries would be relevant to see a patern in the relationship between tech companies and how impact in mental health

# %%
list_country2 = survey_df['Country'].unique()
list_country2
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Bulgaria', 'France',
#        'Portugal', 'Netherlands', 'Switzerland', 'Poland', 'Australia',
#        'Germany', 'Russia', 'Mexico', 'Brazil', 'Slovenia', 'Costa Rica',
#        'Austria', 'Ireland', 'India', 'South Africa', 'Italy', 'Sweden',
#        'Colombia', 'Latvia', 'Romania', 'Belgium', 'New Zealand',
#        'Zimbabwe', 'Spain', 'Finland', 'Uruguay', 'Israel',
#        'Bosnia and Herzegovina', 'Hungary', 'Singapore', 'Japan',
#        'Nigeria', 'Croatia', 'Norway', 'Thailand', 'Denmark',
#        'Bahamas, The', 'Greece', 'Moldova', 'Georgia', 'China',
#        'Czech Republic', 'Philippines'], dtype=object)

# %% [markdown]
# #### We make a count of how many countries are involved in the study

# %%
def num_elem(list):
    count = 0
    for element in list:
        count += 1
    return count

print("Number of countries: ", num_elem(list_country2))
# Out:
# Number of countries:  48

# %% [markdown]
# #### We check the size of the companies and found that some records need to be cleaned due the fact that the system take some as dates.

# %%
print(survey_df['no_employees'].unique())
# Out:
# ['25-Jun' 'More than 1000' '26-100' '100-500' '5-Jan' '500-1000']

# %% [markdown]
# #### We check how many companies are related to technology

# %%
tech_df2 = pd.DataFrame(survey_df, columns=['tech_company'])
dups = tech_df2.pivot_table(columns=['tech_company'], aggfunc='size')
print(dups)
# Out:
# tech_company
# No      228
# Yes    1031
# dtype: int64

# %% [markdown]
# #### The age is relevant to figure if it has any relationship with mental health. Also we can make groups for a data model. Some records show some inconsistency needed to be clean.

# %%
tech_df2 = pd.DataFrame(survey_df, columns=['Age'])
dups = tech_df2.pivot_table(columns=['Age'], aggfunc='size')
print(dups)
# Out:
# Age
# -1726            1
# -29              1
# -1               1
#  5               1
#  8               1
#  11              1
#  18              7
#  19              9
#  20              6
#  21             16
#  22             21
#  23             51
#  24             46
#  25             61
#  26             75
#  27             71
#  28             68
#  29             85
#  30             63
#  31             67
#  32             82
#  33             70
#  34             65
#  35             55
#  36             37
#  37             43
#  38             39
#  39             33
#  40             33
#  41             21
#  42             20
#  43             28
#  44             11
#  45             12
#  46             12
#  47              2
#  48              6
#  49              4
#  50              6
#  51              5
#  53              1
#  54              3
#  55              3
#  56              4
#  57              3
#  58              1
#  60              2
# ...

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### The third dataset was found on Open Sourcing Mental Health (https://osmhhelp.org/). Information of 2016.

# %%
url3 = "https://raw.githubusercontent.com/danieltp92/datasets/main/mental-heath-in-tech-2016_20161114.csv"
survey2 = pd.read_csv(url3)
survey2
# Out:
#       Are you self-employed?  \
# 0                          0
# 1                          0
# 2                          0
# 3                          1
# 4                          0
# ...                      ...
# 1428                       1
# 1429                       1
# 1430                       0
# 1431                       0
# 1432                       0
#
#      How many employees does your company or organization have?  \
# 0                                                26-100
# 1                                                25-Jun
# 2                                                25-Jun
# 3                                                   NaN
# 4                                                25-Jun
# ...                                                 ...
# 1428                                                NaN
# 1429                                                NaN
# 1430                                            100-500
# ...

# %% [markdown]
# ### Reviewing the information from the dataset, we can see that it has 28 variables and a total of 1259 records.

# %%
survey2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1433 entries, 0 to 1432
# Data columns (total 63 columns):
#  #   Column                                                                                                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                                                                                                            --------------  -----
#  0   Are you self-employed?                                                                                                                                                            1433 non-null   int64
#  1   How many employees does your company or organization have?                                                                                                                        1146 non-null   object
# ...

# %% [markdown]
# #### The names of the columns are too complex, this could present an issue to build a code.

# %% [markdown]
# ## Columns relevant for study

# %% [markdown]
# #### The country and number of countries would be relevant to see a patern in the relationship between tech companies and how impact in mental health

# %%
list_country3 = survey2['What country do you live in?'].unique()
list_country3
# Out:
# array(['United Kingdom', 'United States of America', 'Canada', 'Germany',
#        'Netherlands', 'Czech Republic', 'Lithuania', 'Australia',
#        'France', 'Venezuela', 'Poland', 'Belgium', 'Brazil', 'Denmark',
#        'Sweden', 'Russia', 'Spain', 'India', 'Mexico', 'Switzerland',
#        'Norway', 'Argentina', 'Ireland', 'Italy', 'Finland', 'Colombia',
#        'Costa Rica', 'Vietnam', 'Bulgaria', 'New Zealand', 'South Africa',
#        'Slovakia', 'Austria', 'Bangladesh', 'Algeria', 'Pakistan',
#        'Afghanistan', 'Greece', 'Romania', 'Other', 'Brunei', 'Japan',
#        'Iran', 'Hungary', 'Israel', 'Ecuador', 'Bosnia and Herzegovina',
#        'China', 'Chile', 'Guatemala', 'Taiwan', 'Serbia', 'Estonia'],
#       dtype=object)

# %% [markdown]
# #### We make a count of how many countries are involved in the study

# %%
def num_elem(list):
    count = 0
    for element in list:
        count += 1
    return count

print("Number of countries: ", num_elem(list_country3))
# Out:
# Number of countries:  53

# %% [markdown]
# #### We check the size of the companies and found that some records need to be cleaned due the fact that the system take some as dates.

# %%
print(survey2['How many employees does your company or organization have?'].unique())
# Out:
# ['26-100' '25-Jun' nan 'More than 1000' '100-500' '500-1000' '5-Jan']

# %% [markdown]
# #### We check how many companies are related to technology

# %%
tech_df = pd.DataFrame(survey2, columns=['Is your employer primarily a tech company/organization?'])
dups = tech_df.pivot_table(columns=['Is your employer primarily a tech company/organization?'], aggfunc='size')
print(dups)
# Out:
# Is your employer primarily a tech company/organization?
# 0.0    263
# 1.0    883
# dtype: int64

# %% [markdown]
# #### The age is relevant to figure if it has any relationship with mental health. Also we can make groups for a data model.

# %%
tech_df = pd.DataFrame(survey2, columns=['What is your age?'])
dups = tech_df.pivot_table(columns=['What is your age?'], aggfunc='size')
print(dups)
# Out:
# What is your age?
# 3       1
# 15      1
# 17      1
# 19      4
# 20      6
# 21     15
# 22     32
# 23     24
# 24     42
# 25     44
# 26     64
# 27     63
# 28     74
# 29     79
# 30     94
# 31     82
# 32     72
# 33     69
# 34     69
# 35     74
# 36     50
# 37     59
# 38     54
# 39     55
# 40     36
# 41     24
# 42     29
# 43     30
# 44     31
# 45     27
# 46     22
# 47     14
# 48      9
# 49     13
# 50      9
# 51      7
# 52      7
# 53      3
# 54      7
# 55     12
# 56      5
# 57      4
# 58      1
# 59      2
# 61      2
# 62      1
# 63      4
# 65      1
# 66      1
# 70      1
# 74      1
# 99      1
# 323     1
# dtype: int64

# %% [markdown]
# # Although the thir dataset has more records and columns to work, the name of the variables and extra data could be a problem building a code. The second dataset is our best option to work, including the fact that has a datatime that shows records between 2014 and 2016, leading to have an analisys of behavior between years. The first dataset has too low records to work so it would not be a good choice to make a strong analisys.
